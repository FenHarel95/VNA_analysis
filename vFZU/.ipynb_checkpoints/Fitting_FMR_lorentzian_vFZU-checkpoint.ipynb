# %% [markdown]
# <div style="
# font-size:22px;
# font-weight:600;
# color:#1F2933;
# ">
# Requirements:
# <div style="
# font-size:18px;
# font-weight:600;
# color:#1F2933;
# ">
# Compatible with data_handling.py and fit_FMR_class.py (currently only Generalizing-complex-fits branch)
# <div style="
# font-size:22px;
# font-weight:600;
# color:#1F2933;
# ">
# V Original
# <div style="
# font-size:18px;
# font-weight:600;
# color:#1F2933;
# ">

# %%
import h5py
import numpy as np 
import sys

import matplotlib.pyplot as plt

from pathlib import Path

sys.path.append(r"C:\Users\jose1\OneDrive\PostDoc_FZU\DATA_analysis\VNA_data\VNA_analysis")
from data_handling import Analysis_FMR, FitStore
import fit_FMR_class as models
import complex_fits as fits
import fitting_functions as funcs
import resonance_functions as res_func

import ipywidgets as widgets
from ipywidgets import interact

from scipy.optimize import curve_fit

# %% [markdown]
# <div style="
# font-size:22px;
# font-weight:600;
# color:#1F2933;
# ">
# Files Information:
# <div style="
# font-size:18px;
# font-weight:600;
# color:#1F2933;
# ">
# Fill in the information about the files to be analyzed. Create a class entity for each file with Analysis_PSWS()

# %%
#Folders where file are. Keep the r to use raw string in Windows.
address1 = Path(r"C:\Users\jose1\OneDrive\PostDoc_FZU\DATA\joseS\F264N4_p3\inP_010GaAs\FMR_2026-06-10")

# %%
file_name_1 = "2026-06-10_FMR_fsw_0Ato20Ain81_0p5to50GHz_-3dBm_19-41_analysis.h5.ma8"

# %%
sample = "F264N4_p3_inP_010GaAs"

# %%
geometry = "inP" #either "inP" or "outP"

# %%
vna_ref_subtracted = True #Was a reference already subtracted during measurements?

# %%
ansy1 = Analysis_FMR(address1, file_name_1, sample, "FZU_FMR", geometry, vna_ref_subtracted)

# %%
store_in_origin = True #True if you wnat to store fit results in orignal file, otherwise another h5f file is created in the same directory

# %%
if store_in_origin:
    newFile = ansy1.file
else:
    newfile_name =  s.replace(".h5.ma8", "_LorentzFits.h5")
    newFile = address1/newfile_name

fits_storage = FitStore (newFile, group="Lorentzian fitting")

# %% [markdown]
# <div style="
# font-size:22px;
# font-weight:600;
# color:#1F2933;
# ">
# Data visualization:
# <div style="
# font-size:18px;
# font-weight:600;
# color:#1F2933;
# ">
# plot_dL_slider() allows one to preview the data for each field to select the best reference subraction.

# %%
ansy1.plot_dij_slider('d_S', n_0=5)
# Out:
# interactive(children=(IntSlider(value=5, description='Field index', max=80, readout_format='.0f'), Output()), …

# %%
#Ref. subtraction

# %%
ansy1.subtract_ref(single=False, fit=True, nb_g=1, ref_indx= 0) 
############It is saving a fuuuuull matrix of reference, no good

# %%
#Recheck data after new ref

# %%
ansy1.plot_dij_slider('d_S', n_0=5)
# Out:
# interactive(children=(IntSlider(value=5, description='Field index', max=80, readout_format='.0f'), Output()), …

# %%
# Example of a single fit

# %%
ini_vals = [1, 1, 35, 0.028, 0, 0] #A, w, fres, fper, fref, re0, im0
H_index = 40

f_min, f_max = 30, 40 #GHz
f_array = ansy1.freqs
y_array_re, y_array_im = ansy1.d_S("21R")[H_index], ansy1.d_S("21I")[H_index]

model = models.ComplexLorentzian_freq()
fitter = fits.ComplexFitter( ini_vals, f_min, f_max,
    f_array, y_array_re , y_array_im, model)
fitter.fix(fo=35, df=0.02, re0=0, im0=0) # Parameters to be fixed, empty otherwise
opt_p0 = fitter.simplex_wpm(method='Nelder-Mead')#'Powell'
print(opt_p0)
print("Initial simplex fit")
fitter.plot_fit_simplex_wpm()

new_p0 = np.array(list(opt_p0.values()), dtype=float)
fitter.update_p0(new_p0)

params, cov = fitter.fit(simplex_b=False)
print("Final fit and results")
fitter.plot_fit()
fitter.summary()
print(f"The phase is: {model.phase_deg(**params)}")
# Out:
# {'Ar': -0.00012017708154651699, 'Ai': -0.00015990123670768332, 'fo': 35.0, 'df': 0.02, 're0': 0.0, 'im0': 0.0}
# Initial simplex fit
# Final fit and results
# Fit Results
# ----------------------------------------------------------------------
# Parameter                  Value        ± Error      Unit     Fixed
# ----------------------------------------------------------------------
# Ar                    -1.178e-04      1.109e-05         U        No
# Ai                    -5.779e-04      1.109e-05         U        No
# fo                       35.0921         0.0023       GHz        No
# df                        0.0892         0.0023       GHz        No
# re0                    1.584e-04      1.454e-05         U        No
# im0                    2.320e-05      1.454e-05         U        No
# ----------------------------------------------------------------------
# The phase is: 258.4778846355312

# %%
#If we are happy with the fit, we can save it.

# %%
fit_dict = fitter.export_fit_dict()

#fits_storage.save(index=H_index,field=float(ansy1.calc_field("inP")[H_index]),fit_dict=fit_dict)

# %%
# Automatic fitting of entire spectra. Enter the estimated parameters for the Kittel model guiding the automatic fitting.

# %%
est_gamma = 28.8 #GHz/T
est_hx = 2.180 #T
est_hy = 0.04 #T

for i in range(len(ansy1.curr)):
    H_index = i
    freq = res_func.kittel_general(ansy1.calc_field("inP")[H_index],est_gamma, est_hx, est_hy)
    print(f"Guide freq.={freq}")
    ini_vals = [1, 1, freq, 0.028, 0, 0] #A, w, fres, fper, fref, re0, im0

    
    f_min, f_max = freq-10, freq+10 #GHz
    f_array = ansy1.freqs
    y_array_re, y_array_im = ansy1.d_S("21R")[H_index], ansy1.d_S("21I")[H_index]
    
    model = models.ComplexLorentzian_freq()
    fitter = fits.ComplexFitter( ini_vals, f_min, f_max,
        f_array, y_array_re , y_array_im, model)
    fitter.fix(fo=freq, df=0.02, re0=0, im0=0) # Parameters to be fixed, empty otherwise
    opt_p0 = fitter.simplex_wpm(method='Nelder-Mead')#'Powell'
    #print(opt_p0)
    #fitter.plot_fit_simplex_wpm()
    new_p0 = np.array(list(opt_p0.values()), dtype=float)
    fitter.update_p0(new_p0)
    
    params, cov = fitter.fit(simplex_b=False)
    fitter.plot_fit()
    fitter.summary()
    fit_dict = fitter.export_fit_dict()
    fits_storage.save(index=H_index,field=float(ansy1.calc_field("inP")[H_index]),fit_dict=fit_dict)
# Out:
# 52.770204347579124
# Fit Results
# ----------------------------------------------------------------------
# Parameter                  Value        ± Error      Unit     Fixed
# ----------------------------------------------------------------------
# Ar                     6.371e-05      6.922e-06         U        No
# Ai                    -1.722e-04      6.922e-06         U        No
# fo                       49.6959         0.0121       GHz        No
# df                        0.2828         0.0121       GHz        No
# re0                    4.333e-05      4.550e-06         U        No
# im0                    4.578e-05      4.550e-06         U        No
# ----------------------------------------------------------------------
# 52.455851435617085
# Fit Results
# ----------------------------------------------------------------------
# Parameter                  Value        ± Error      Unit     Fixed
# ----------------------------------------------------------------------
# Ar                     1.694e-04      7.084e-06         U        No
# Ai                    -1.719e-04      7.084e-06         U        No
# fo                       49.7921         0.0079       GHz        No
# df                        0.2362         0.0079       GHz        No
# re0                    8.468e-05      4.817e-06         U        No
# im0                    2.993e-05      4.817e-06         U        No
# ----------------------------------------------------------------------
# 52.134133083477195
# Fit Results
# ----------------------------------------------------------------------
# Parameter                  Value        ± Error      Unit     Fixed
# ----------------------------------------------------------------------
# Ar                     2.728e-04      5.794e-06         U        No
# Ai                    -6.384e-05      5.794e-06         U        No
# fo                       49.8156         0.0038       GHz        No
# df                        0.1562         0.0038       GHz        No
# re0                    1.183e-04      5.047e-06         U        No
# im0                   -1.872e-05      5.047e-06         U        No
# ----------------------------------------------------------------------
# 51.81755723444493
# Fit Results
# ----------------------------------------------------------------------
# Parameter                  Value        ± Error      Unit     Fixed
# ----------------------------------------------------------------------
# Ar                     2.639e-04      4.796e-06         U        No
# Ai                    -5.950e-05      4.796e-06         U        No
# fo                       49.6578         0.0027       GHz        No
# df                        0.1215         0.0027       GHz        No
# re0                    1.242e-04      5.330e-06         U        No
# im0                   -2.931e-05      5.330e-06         U        No
# ----------------------------------------------------------------------
# 51.478722018699926
# Fit Results
# ----------------------------------------------------------------------
# Parameter                  Value        ± Error      Unit     Fixed
# ----------------------------------------------------------------------
# Ar                     2.265e-04      4.599e-06         U        No
# Ai                    -1.383e-04      4.599e-06         U        No
# fo                       49.4375         0.0025       GHz        No
# df                        0.1083         0.0025       GHz        No
# re0                    1.253e-04      5.603e-06         U        No
# im0                   -3.762e-06      5.603e-06         U        No
# ----------------------------------------------------------------------
# 51.129456361177716
# Fit Results
# ----------------------------------------------------------------------
# Parameter                  Value        ± Error      Unit     Fixed
# ----------------------------------------------------------------------
# Ar                     1.278e-04      4.644e-06         U        No
# Ai                    -2.255e-04      4.644e-06         U        No
# fo                       49.1841         0.0025       GHz        No
# df                        0.1042         0.0025       GHz        No
# re0                    1.135e-04      5.779e-06         U        No
# im0                    3.978e-05      5.779e-06         U        No
# ----------------------------------------------------------------------
# 50.768500617562246
# Fit Results
# ----------------------------------------------------------------------
# Parameter                  Value        ± Error      Unit     Fixed
# ----------------------------------------------------------------------
# Ar                    -6.433e-06      4.635e-06         U        No
# Ai                    -2.544e-04      4.635e-06         U        No
# fo                       48.9268         0.0025       GHz        No
# df                        0.0991         0.0025       GHz        No
# re0                    8.131e-05      5.870e-06         U        No
# im0                    7.766e-05      5.870e-06         U        No
# ----------------------------------------------------------------------
# 50.394603338867164
# Fit Results
# ----------------------------------------------------------------------
# Parameter                  Value        ± Error      Unit     Fixed
# ----------------------------------------------------------------------
# Ar                    -1.524e-04      4.660e-06         U        No
# Ai                    -1.947e-04      4.660e-06         U        No
# fo                       48.6458         0.0026       GHz        No
# df                        0.0991         0.0026       GHz        No
# re0                    3.114e-05      5.821e-06         U        No
# im0                    9.749e-05      5.821e-06         U        No
# ----------------------------------------------------------------------
# 49.99076982669881
# Fit Results
# ----------------------------------------------------------------------
# Parameter                  Value        ± Error      Unit     Fixed
# ----------------------------------------------------------------------
# Ar                    -2.299e-04      4.592e-06         U        No
# Ai                    -5.185e-05      4.592e-06         U        No
# fo                       48.3442         0.0026       GHz        No
# df                        0.0985         0.0026       GHz        No
# re0                   -1.888e-05      5.663e-06         U        No
# im0                    8.817e-05      5.663e-06         U        No
# ----------------------------------------------------------------------
# 49.58702725089878
# Fit Results
# ----------------------------------------------------------------------
# Parameter                  Value        ± Error      Unit     Fixed
# ----------------------------------------------------------------------
# Ar                    -1.974e-04      4.508e-06         U        No
# Ai                     1.076e-04      4.508e-06         U        No
# fo                       48.0324         0.0027       GHz        No
# df                        0.0973         0.0027       GHz        No
# re0                   -5.391e-05      5.503e-06         U        No
# im0                    5.173e-05      5.503e-06         U        No
# ----------------------------------------------------------------------
# 49.18446079213842
# Fit Results
# ----------------------------------------------------------------------
# Parameter                  Value        ± Error      Unit     Fixed
# ----------------------------------------------------------------------
# Ar                    -7.708e-05      4.504e-06         U        No
# Ai                     2.028e-04      4.504e-06         U        No
# fo                       47.7068         0.0028       GHz        No
# df                        0.0990         0.0028       GHz        No
# re0                   -6.391e-05      5.359e-06         U        No
# im0                    9.450e-06      5.359e-06         U        No
# ----------------------------------------------------------------------
# 48.749043595059725
# Fit Results
# ----------------------------------------------------------------------
# Parameter                  Value        ± Error      Unit     Fixed
# ----------------------------------------------------------------------
# Ar                     9.265e-05      4.579e-06         U        No
# Ai                     2.017e-04      4.579e-06         U        No
# fo                       47.3520         0.0028       GHz        No
# df                        0.0975         0.0028       GHz        No
# re0                   -4.665e-05      5.396e-06         U        No
# im0                   -3.701e-05      5.396e-06         U        No
# ----------------------------------------------------------------------
# 48.2786252270335
# Fit Results
# ----------------------------------------------------------------------
# Parameter                  Value        ± Error      Unit     Fixed
# ----------------------------------------------------------------------
# Ar                     2.250e-04      4.671e-06         U        No
# Ai                     8.443e-05      4.671e-06         U        No
# fo                       47.0029         0.0026       GHz        No
# df                        0.0959         0.0026       GHz        No
# re0                    9.431e-07      5.447e-06         U        No
# im0                   -6.247e-05      5.447e-06         U        No
# ----------------------------------------------------------------------
# 47.8095798643413
# Fit Results
# ----------------------------------------------------------------------
# Parameter                  Value        ± Error      Unit     Fixed
# ----------------------------------------------------------------------
# Ar                     2.222e-04      4.705e-06         U        No
# Ai                    -1.328e-04      4.705e-06         U        No
# fo                       46.6327         0.0024       GHz        No
# df                        0.0938         0.0024       GHz        No
# re0                    5.987e-05      5.446e-06         U        No
# im0                   -4.185e-05      5.446e-06         U        No
# ----------------------------------------------------------------------
# 47.32470268683053
# Fit Results
# ----------------------------------------------------------------------
# Parameter                  Value        ± Error      Unit     Fixed
# ----------------------------------------------------------------------
# Ar                     4.016e-05      4.743e-06         U        No
# Ai                    -2.680e-04      4.743e-06         U        No
# fo                       46.2608         0.0023       GHz        No
# df                        0.0935         0.0023       GHz        No
# re0                    7.748e-05      5.398e-06         U        No
# im0                    1.644e-05      5.398e-06         U        No
# ----------------------------------------------------------------------
# 46.82491642065715
# Fit Results
# ----------------------------------------------------------------------
# Parameter                  Value        ± Error      Unit     Fixed
# ----------------------------------------------------------------------
# Ar                    -1.804e-04      4.680e-06         U        No
# Ai                    -2.151e-04      4.680e-06         U        No
# fo                       45.8937         0.0021       GHz        No
# df                        0.0923         0.0021       GHz        No
# re0                    4.177e-05      5.262e-06         U        No
# im0                    6.711e-05      5.262e-06         U        No
# ----------------------------------------------------------------------
# 46.31149389100879
# Fit Results
# ----------------------------------------------------------------------
# Parameter                  Value        ± Error      Unit     Fixed
# ----------------------------------------------------------------------
# Ar                    -2.771e-04      4.597e-06         U        No
# Ai                    -1.547e-06      4.597e-06         U        No
# fo                       45.5167         0.0021       GHz        No
# df                        0.0914         0.0021       GHz        No
# re0                   -1.514e-05      5.101e-06         U        No
# im0                    6.837e-05      5.101e-06         U        No
# ----------------------------------------------------------------------
# 45.78602843935194
# Fit Results
# ----------------------------------------------------------------------
# Parameter                  Value        ± Error      Unit     Fixed
# ----------------------------------------------------------------------
# Ar                    -1.775e-04      4.519e-06         U        No
# Ai                     2.086e-04      4.519e-06         U        No
# fo                       45.1323         0.0021       GHz        No
# df                        0.0915         0.0021       GHz        No
# re0                   -5.244e-05      4.920e-06         U        No
# im0                    3.184e-05      4.920e-06         U        No
# ----------------------------------------------------------------------
# 45.25039211177676
# Fit Results
# ----------------------------------------------------------------------
# Parameter                  Value        ± Error      Unit     Fixed
# ----------------------------------------------------------------------
# Ar                     5.562e-05      4.418e-06         U        No
# Ai                     2.579e-04      4.418e-06         U        No
# fo                       44.7300         0.0022       GHz        No
# df                        0.0934         0.0022       GHz        No
# re0                   -4.714e-05      4.677e-06         U        No
# im0                   -1.724e-05      4.677e-06         U        No
# ----------------------------------------------------------------------
# 44.70668337150843
# Fit Results
# ----------------------------------------------------------------------
# Parameter                  Value        ± Error      Unit     Fixed
# ----------------------------------------------------------------------
# Ar                     2.309e-04      4.350e-06         U        No
# Ai                     1.160e-04      4.350e-06         U        No
# fo                       44.3184         0.0022       GHz        No
# df                        0.0936         0.0022       GHz        No
# re0                   -1.249e-05      4.519e-06         U        No
# im0                   -4.222e-05      4.519e-06         U        No
# ----------------------------------------------------------------------
# 44.15716636847899
# Fit Results
# ----------------------------------------------------------------------
# Parameter                  Value        ± Error      Unit     Fixed
# ----------------------------------------------------------------------
# Ar                     2.424e-04      4.482e-06         U        No
# Ai                    -1.170e-04      4.482e-06         U        No
# fo                       43.8985         0.0021       GHz        No
# df                        0.0923         0.0021       GHz        No
# re0                    2.290e-05      4.609e-06         U        No
# im0                   -3.230e-05      4.609e-06         U        No
# ----------------------------------------------------------------------
# 43.626358616136145
# Fit Results
# ----------------------------------------------------------------------
# Parameter                  Value        ± Error      Unit     Fixed
# ----------------------------------------------------------------------
# Ar                     4
# Fit Results
# ----------------------------------------------------------------------
# Parameter                  Value        ± Error      Unit     Fixed
# ----------------------------------------------------------------------
# Ar                    -2.852e-04      5.238e-06         U        No
# Ai                     2.607e-04      5.238e-06         U        No
# fo                       39.6448         0.0017       GHz        No
# df                        0.0901         0.0017       GHz        No
# re0                   -5.926e-05      4.862e-06         U        No
# im0                    4.902e-05      4.862e-06         U        No
# ----------------------------------------------------------------------
# 38.35722749021621
# Fit Results
# ----------------------------------------------------------------------
# Parameter                  Value        ± Error      Unit     Fixed
# ----------------------------------------------------------------------
# Ar                     5.744e-05      5.350e-06         U        No
# Ai                     3.947e-04      5.350e-06         U        No
# fo                       39.2079         0.0017       GHz        No
# df                        0.0895         0.0017       GHz        No
# re0                   -7.708e-05      4.983e-06         U        No
# im0                   -2.318e-06      4.983e-06         U        No
# ----------------------------------------------------------------------
# 37.883703690746835
# Fit Results
# ----------------------------------------------------------------------
# Parameter                  Value        ± Error      Unit     Fixed
# ----------------------------------------------------------------------
# Ar                     3.761e-04      5.613e-06         U        No
# Ai                     1.800e-04      5.613e-06         U        No
# fo                       38.7684         0.0017       GHz        No
# df                        0.0876         0.0017       GHz        No
# re0                   -4.379e-05      5.284e-06         U        No
# im0                   -4.435e-05      5.284e-06         U        No
# ----------------------------------------------------------------------
# 37.40198385004499
# Fit Results
# ----------------------------------------------------------------------
# Parameter                  Value        ± Error      Unit     Fixed
# ----------------------------------------------------------------------
# Ar                     3.641e-04      5.820e-06         U        No
# Ai                    -2.218e-04      5.820e-06         U        No
# fo                       38.3304         0.0017       GHz        No
# df                        0.0865         0.0017       GHz        No
# re0                    1.967e-05      5.513e-06         U        No
# im0                   -4.409e-05      5.513e-06         U        No
# ----------------------------------------------------------------------
# 36.96600534698633
# Fit Results
# ----------------------------------------------------------------------
# Parameter                  Value        ± Error      Unit     Fixed
# ----------------------------------------------------------------------
# Ar                    -6.081e-06      5.943e-06         U        No
# Ai                    -4.323e-04      5.943e-06         U        No
# fo                       37.8837         0.0017       GHz        No
# df                        0.0859         0.0017       GHz        No
# re0                    5.484e-05      5.650e-06         U        No
# im0                    5.389e-06      5.650e-06         U        No
# ----------------------------------------------------------------------
# 36.51938480679561
# Fit Results
# ----------------------------------------------------------------------
# Parameter                  Value        ± Error      Unit     Fixed
# ----------------------------------------------------------------------
# Ar                    -3.760e-04      6.160e-06         U        No
# Ai                    -2.092e-04      6.160e-06         U        No
# fo                       37.4337         0.0017       GHz        No
# df                        0.0871         0.0017       GHz        No
# re0                    2.096e-05      5.816e-06         U        No
# im0                    5.457e-05      5.816e-06         U        No
# ----------------------------------------------------------------------
# 36.06133998033725
# Fit Results
# ----------------------------------------------------------------------
# Parameter                  Value        ± Error      Unit     Fixed
# ----------------------------------------------------------------------
# Ar                    -3.653e-04      6.378e-06         U        No
# Ai                     2.271e-04      6.378e-06         U        No
# fo                       36.9678         0.0018       GHz        No
# df                        0.0889         0.0018       GHz        No
# re0                   -4.416e-05      5.961e-06         U        No
# im0                    4.721e-05      5.961e-06         U        No
# ----------------------------------------------------------------------
# 35.64265562564687
# Fit Results
# ----------------------------------------------------------------------
# Parameter                  Value        ± Error      Unit     Fixed
# ----------------------------------------------------------------------
# Ar                     2.834e-05      6.748e-06         U        No
# Ai                     4.527e-04      6.748e-06         U        No
# fo                       36.4998         0.0018       GHz        No
# df                        0.0887         0.0018       GHz        No
# re0                   -7.262e-05      6.315e-06         U        No
# im0                   -1.441e-05      6.315e-06         U        No
# ----------------------------------------------------------------------
# 35.19157629676557
# Fit Results
# ----------------------------------------------------------------------
# Parameter                  Value        ± Error      Unit     Fixed
# ----------------------------------------------------------------------
# Ar                     4.414e-04      7.085e-06         U        No
# Ai                     2.049e-04      7.085e-06         U        No
# fo                       36.0307         0.0018       GHz        No
# df                        0.0887         0.0018       GHz        No
# re0                   -3.197e-05      6.627e-06         U        No
# im0                   -7.468e-05      6.627e-06         U        No
# ----------------------------------------------------------------------
# 34.758354727496865
# Fit Results
# ----------------------------------------------------------------------
# Parameter                  Value        ± Error      Unit     Fixed
# ----------------------------------------------------------------------
# Ar                     4.120e-04      7.553e-06         U        No
# Ai                    -3.373e-04      7.553e-06         U        No
# fo                       35.5564         0.0018       GHz        No
# df                        0.0890         0.0018       GHz        No
# re0                    5.112e-05      7.056e-06         U        No
# im0                   -6.647e-05      7.056e-06         U        No
# ----------------------------------------------------------------------
# 34.32375218613163
# Fit Results
# ----------------------------------------------------------------------
# Parameter                  Value        ± Error      Unit     Fixed
# ----------------------------------------------------------------------
# Ar                    -1.171e-04      7.828e-06         U        No
# Ai                    -5.634e-04      7.828e-06         U        No
# fo                       35.0916         0.0017       GHz        No
# df                        0.0876         0.0017       GHz        No
# re0                    8.312e-05      7.372e-06         U        No
# im0                    1.529e-05      7.372e-06         U        No
# ----------------------------------------------------------------------
# 33.88603032865781
# Fit Results
# ----------------------------------------------------------------------
# Parameter                  Value        ± Error      Unit     Fixed
# ----------------------------------------------------------------------
# Ar                    -5.748e-04      7.847e-06         U        No
# Ai                    -1.598e-04      7.847e-06         U        No
# fo                       34.6297         0.0016       GHz        No
# df                        0.0878         0.0016       GHz        No
# re0                    2.243e-05      7.382e-06         U        No
# im0                    8.300e-05      7.382e-06         U        No
# ----------------------------------------------------------------------
# 33.44363033824672
# Fit Results
# ----------------------------------------------------------------------
# Parameter                  Value        ± Error      Unit     Fixed
# ----------------------------------------------------------------------
# Ar                    -4.017e-04      7.679e-06         U        No
# Ai                     4.018e-04      7.679e-06         U        No
# fo                       34.1666         0.0017       GHz        No
# df                        0.0892         0.0017       GHz        No
# re0                   -5.598e-05      7.163e-06         U        No
# im0                    5.132e-05      7.163e-06         U        No
# ----------------------------------------------------------------------
# 32.99522834204988
# Fit Results
# ----------------------------------------------------------------------
# Parameter                  Value        ± Error      Unit     Fixed
# ----------------------------------------------------------------------
# Ar                     1.501e-04      7.837e-06         U        No
# Ai                     5.325e-04      7.837e-06         U        No
# fo                       33.6839         0.0018       GHz        No
# df                        0.0906         0.0018       GHz        No
# re0                   -6.401e-05      7.256e-06         U        No
# im0                   -3.219e-05      7.256e-06         U        No
# ----------------------------------------------------------------------
# 32.53978024903814
# Fit Results
# ----------------------------------------------------------------------
# Parameter                  Value        ± Error      Unit     Fixed
# ----------------------------------------------------------------------
# Ar                     5.501e-04      8.332e-06         U        No
# Ai                     1.207e-04      8.332e-06         U        No
# fo                       33.1955         0.0019       GHz        No
# df                        0.0900         0.0019       GHz        No
# re0                    5.413e-06      7.738e-06         U        No
# im0                   -8.997e-05      7.738e-06         U        No
# ----------------------------------------------------------------------
# 32.07655397276634
# Fit Results
# ----------------------------------------------------------------------
# Parameter                  Value        ± Error      Unit     Fixed
# ----------------------------------------------------------------------
# Ar                     3.569e-04      9.044e-06         U        No
# Ai                    -4.846e-04      9.044e-06         U        No
# fo                       32.6943         0.0019       GHz        No
# df                        0.0890         0.0019       GHz        No
# re0                    1.053e-04      8.448e-06         U        No
# im0                   -6.546e-05      8.448e-06         U        No
# ----------------------------------------------------------------------
# 31.605147368684545
# Fit Results
# ----------------------------------------------------------------------
# Parameter                  Value        ± Error      Unit     Fixed
# ----------------------------------------------------------------------
# Ar                    -3.421e-04      9.757e-06         U        No
# Ai                    -5.705e-04      9.757e-06         U        No
# fo                       32.1956         0.0018       GHz        No
# df                        0.0869         0.0018       GHz        No
# re0                    1.248e-04      9.226e-06         U        No
# im0                    4.297e-05      9.226e-06         U        No
# ----------------------------------------------------------------------
# 31.12549063117748
# Fit Results
# ----------------------------------------------------------------------
# Parameter                  Value        ± Error      Unit     Fixed
# ----------------------------------------------------------------------
# Ar                    -7.081e-04      1.027e-05         U        No
# Ai                     9.963e-05      1.027e-05         U        No
# fo                       31.7077         0.0017       GHz        No
# df                        0.0854         0.0017       GHz        No
# re0                    2.581e-05      9.797e-06         U        No
# im0                    9.895e-05      9.797e-06         U        No
# ----------------------------------------------------------------------
# 30.637832357486253
# Fit Results
# ----------------------------------------------------------------------
# Parameter                  Value        ± Error      Unit     Fixed
# ----------------------------------------------------------------------
# Ar                    -1.743e-04      1.059e-05         U        No
# Ai                     7.161e-04      1.059e-05         U        No
# fo                       31.2148         0.0017       GHz        No
# df                        0.0868         0.0017       GHz        No
# re0                   -6.142e-05      1.002e-05         U        No
# im0                    1.390e-05      1.002e-05         U        No
# ----------------------------------------------------------------------
# 30.14270899480178
# Fit Results
# ----------------------------------------------------------------------
# Parameter                  Value        ± Error      Unit     Fixed
# ----------------------------------------------------------------------
# Ar                     5
# Fit Results
# ----------------------------------------------------------------------
# Parameter                  Value        ± Error      Unit     Fixed
# ----------------------------------------------------------------------
# Ar                       -0.0011      2.871e-05         U        No
# Ai                    -5.258e-04      2.871e-05         U        No
# fo                       13.0302         0.0039       GHz        No
# df                        0.1154         0.0039       GHz        No
# re0                    1.691e-04      2.351e-05         U        No
# im0                    1.994e-04      2.351e-05         U        No
# ----------------------------------------------------------------------
# 11.508320253764508
# Fit Results
# ----------------------------------------------------------------------
# Parameter                  Value        ± Error      Unit     Fixed
# ----------------------------------------------------------------------
# Ar                     1.338e-04      2.888e-05         U        No
# Ai                        0.0012      2.888e-05         U        No
# fo                       12.1035         0.0043       GHz        No
# df                        0.1255         0.0043       GHz        No
# re0                   -1.731e-04      2.266e-05         U        No
# im0                    1.738e-05      2.266e-05         U        No
# ----------------------------------------------------------------------
# 10.41066483989293
# Fit Results
# ----------------------------------------------------------------------
# Parameter                  Value        ± Error      Unit     Fixed
# ----------------------------------------------------------------------
# Ar                     7.916e-04      2.873e-05         U        No
# Ai                    -5.319e-04      2.873e-05         U        No
# fo                       11.1163         0.0055       GHz        No
# df                        0.1303         0.0055       GHz        No
# re0                    1.450e-04      2.217e-05         U        No
# im0                   -1.125e-04      2.217e-05         U        No
# ----------------------------------------------------------------------
# 9.137722413909831
# Fit Results
# ----------------------------------------------------------------------
# Parameter                  Value        ± Error      Unit     Fixed
# ----------------------------------------------------------------------
# Ar                    -7.966e-04      2.971e-05         U        No
# Ai                     4.827e-04      2.971e-05         U        No
# fo                        9.8729         0.0055       GHz        No
# df                        0.1227         0.0055       GHz        No
# re0                   -2.028e-05      2.441e-05         U        No
# im0                    1.898e-04      2.441e-05         U        No
# ----------------------------------------------------------------------

# %%
#Realoading parameters

# %%
data_L_fits = fits_storage.load_fit_results(newFile, group="Lorentzian fitting")

# %%
#Plotting of fitted parameters

# %%
fits_storage.plot_fit_parameters(
    data_L_fits,
    x_axis="field",
    params=["fo"]
)

# %%
#Fitting f. resonance vs H to the Kittel model

# %%
H_data= data_L_fits["field"]
f_data= data_L_fits["fo"]

gamma_fix = True
gamma_fixed = 28.8

if gamma_fix:
    function = lambda H, Hx, Hy: res_func.kittel_general(H, gamma_fixed, Hx, Hy)
    p0 = [2.18, 0.04]  # initial guess: gamma ~ 28 GHz/T (electron-like)
    lower_bounds = [ 1.8, -1.0]
    upper_bounds = [2.5,  0.2]
else:
    function = res_func.kittel_general
    p0 = [28.8, 2.18, 0.04]  # initial guess: gamma ~ 28 GHz/T (electron-like)
    lower_bounds = [28.2, 1.8, -1.0]
    upper_bounds = [29.2,  2.5,  0.2]
    
popt, pcov = curve_fit(
    function,
    H_data,
    f_data,
    p0=p0,
    bounds=(lower_bounds, upper_bounds)
)


perr = np.sqrt(np.diag(pcov))  # 1-sigma errors

H_fit = np.linspace(H_data.min(), H_data.max(), 200)
if gamma_fix:
    Hx_fit, Hy_fit = popt
    f_fit = res_func.kittel_general(H_fit, gamma_fixed, Hx_fit, Hy_fit)
    gamma_fit=gamma_fixed
else:
    gamma_fit, Hx_fit, Hy_fit = popt
    f_fit = res_func.kittel_general(H_fit, gamma_fit, Hx_fit, Hy_fit)

plt.scatter(H_data, f_data, label="Resoance f.")

plt.plot(H_fit, f_fit, label="Kittel fit", color="red")

plt.xlabel("H (T)")
plt.ylabel("Frequency (GHz)")
plt.legend()
plt.show()
print(f"gamma={gamma_fit}GHz/T, Hx={Hx_fit}T, Hy={Hy_fit}T")
# Out:
# gamma=28.8GHz/T, Hx=2.051612299631103T, Hy=0.061867293435574844T
