# %% [markdown]
# <div style="
# font-size:22px;
# font-weight:600;
# color:#1F2933;
# ">
# Requirements:
# <div style="
# font-size:18px;
# font-weight:600;
# color:#1F2933;
# ">
# Compatible with data_handling.py and fit_FMR_class.py (currently only Generalizing-complex-fits branch)
# <div style="
# font-size:22px;
# font-weight:600;
# color:#1F2933;
# ">
# V Original
# <div style="
# font-size:18px;
# font-weight:600;
# color:#1F2933;
# ">

# %%
import h5py
import numpy as np 
import sys

import matplotlib.pyplot as plt

from pathlib import Path

sys.path.append(r"C:\Users\jose1\OneDrive\PostDoc_FZU\DATA_analysis\VNA_data\VNA_analysis")
from data_handling import Analysis_FMR, FitStore
import fit_FMR_class as models
import complex_fits as fits
import fitting_functions as funcs
import resonance_functions as res_func
import calculators as calcs

import ipywidgets as widgets
from ipywidgets import interact

from scipy.optimize import curve_fit

# %% [markdown]
# <div style="
# font-size:22px;
# font-weight:600;
# color:#1F2933;
# ">
# Files Information:
# <div style="
# font-size:18px;
# font-weight:600;
# color:#1F2933;
# ">
# Fill in the information about the files to be analyzed. Create a class entity for each file with Analysis_PSWS()

# %%
#Folders where file are. Keep the r to use raw string in Windows.
address1 = Path(r"C:\Users\jose1\OneDrive\PostDoc_FZU\DATA\joseS\F264N4\inP_1m10\FMR_2026-06-05")

# %%
file_name_1 = "2026-06-05_FMR_fsw_0Ato19p5Ain81_0p5to50GHz_-3dBm_20-57_analysis.h5.ma8"

# %%
sample = "F264N4_inP_1m10GaAs"

# %%
geometry = "inP" #either "inP" or "outP"

# %%
vna_ref_subtracted = True #Was a reference already subtracted during measurements?

# %%
ansy1 = Analysis_FMR(address1, file_name_1, sample, "FZU_FMR", geometry, vna_ref_subtracted)

# %%
store_in_origin = True #True if you wnat to store fit results in orignal file, otherwise another h5f file is created in the same directory

# %%
if store_in_origin:
    newFile = ansy1.file
else:
    newfile_name =  s.replace(".h5.ma8", "_LorentzFits.h5")
    newFile = address1/newfile_name

fits_storage = FitStore (newFile, group="Lorentzian fitting")

# %% [markdown]
# <div style="
# font-size:22px;
# font-weight:600;
# color:#1F2933;
# ">
# Data visualization:
# <div style="
# font-size:18px;
# font-weight:600;
# color:#1F2933;
# ">
# plot_dL_slider() allows one to preview the data for each field to select the best reference subraction.

# %%
ansy1.plot_dij_slider('d_S', n_0=5)
# Out:
# interactive(children=(IntSlider(value=5, description='Field index', max=80, readout_format='.0f'), Output()), …

# %%
#Ref. subtraction

# %%
ansy1.subtract_ref(single=False, fit=True, nb_g=1, ref_indx= 0) 
# ############It is saving a fuuuuull matrix of reference, no good

# %%
#Recheck data after new ref

# %%
ansy1.plot_dij_slider('d_S', n_0=5)
# Out:
# interactive(children=(IntSlider(value=5, description='Field index', max=80, readout_format='.0f'), Output()), …

# %%
# Example of a single fit

# %%
ini_vals = [1, 1, 35, 0.028, 0, 0] #A, w, fres, fper, fref, re0, im0
H_index = 40

f_min, f_max = 25, 35 #GHz
f_array = ansy1.freqs



y_array_re, y_array_im = ansy1.d_S("21R")[H_index], ansy1.d_S("21I")[H_index]

model = models.ComplexLorentzian_freq()
fitter = fits.ComplexFitter( ini_vals, f_min, f_max,
    f_array, y_array_re , y_array_im, model)
fitter.fix(fo=30.5, df=0.02, re0=0, im0=0) # Parameters to be fixed, empty otherwise
opt_p0 = fitter.simplex_wpm(method='Nelder-Mead')#'Powell'
print(opt_p0)
print("Initial simplex fit")
fitter.plot_fit_simplex_wpm()

new_p0 = np.array(list(opt_p0.values()), dtype=float)
fitter.update_p0(new_p0)

params, cov = fitter.fit(simplex_b=False)
print("Final fit and results")
fitter.plot_fit()
fitter.summary()
print(f"The phase is: {model.phase_deg(**params)}")
# Out:
# {'Ar': -7.359646766040932e-05, 'Ai': -0.00013551195848102, 'fo': 30.5, 'df': 0.02, 're0': 0.0, 'im0': 0.0}
# Initial simplex fit
# Final fit and results
# Fit Results
# ----------------------------------------------------------------------
# Parameter                  Value        ± Error      Unit     Fixed
# ----------------------------------------------------------------------
# Ar                     9.733e-04      2.162e-05         U        No
# Ai                    -2.799e-07      2.162e-05         U        No
# fo                       30.8478         0.0028       GHz        No
# df                        0.0901         0.0028       GHz        No
# re0                    2.193e-05      2.820e-05         U        No
# im0                   -3.088e-04      2.820e-05         U        No
# ----------------------------------------------------------------------
# The phase is: 359.9835248468677

# %%
#If we are happy with the fit, we can save it.

# %%
fit_dict = fitter.export_fit_dict()

#fits_storage.save(index=H_index,field=float(ansy1.calc_field("inP")[H_index]),fit_dict=fit_dict)

# %%
# Automatic fitting of entire spectra. Enter the estimated parameters for the Kittel model guiding the automatic fitting.

# %%
est_gamma = 28.8 #GHz/T
est_hx = 2090.5/1000 #T
est_hy = -58/1000 #T

for i in range(15,72+1):
    H_index = i
    freq = res_func.kittel_general(ansy1.calc_field("inP")[H_index],est_gamma, est_hx, est_hy)
    print(f"Index= {i}, Guide freq.={freq}")
    ini_vals = [1, 1, freq, 0.028, 0, 0] #A, w, fres, fper, fref, re0, im0

    
    f_min, f_max = freq-3, freq+3 #GHz
    f_array = ansy1.freqs
    y_array_re, y_array_im = ansy1.d_S("21R")[H_index], ansy1.d_S("21I")[H_index]
    
    model = models.ComplexLorentzian_freq()
    fitter = fits.ComplexFitter( ini_vals, f_min, f_max,
        f_array, y_array_re , y_array_im, model)
    fitter.fix(fo=freq, df=0.02, re0=0, im0=0) # Parameters to be fixed, empty otherwise
    opt_p0 = fitter.simplex_wpm(method='Nelder-Mead')#'Powell'
    #print(opt_p0)
    #fitter.plot_fit_simplex_wpm()
    new_p0 = np.array(list(opt_p0.values()), dtype=float)
    fitter.update_p0(new_p0)
    
    params, cov = fitter.fit(simplex_b=False)
    fitter.plot_fit()
    fitter.summary()
    fit_dict = fitter.export_fit_dict()
    fits_storage.save(index=H_index,field=float(ansy1.calc_field("inP")[H_index]),fit_dict=fit_dict)
# Out:
# Guide freq.=42.62075513692857
# Fit Results
# ----------------------------------------------------------------------
# Parameter                  Value        ± Error      Unit     Fixed
# ----------------------------------------------------------------------
# Ar                     7.272e-04      2.114e-05         U        No
# Ai                     1.628e-04      2.114e-05         U        No
# fo                       41.9415         0.0036       GHz        No
# df                        0.0918         0.0036       GHz        No
# re0                   -7.548e-05      3.498e-05         U        No
# im0                   -3.947e-04      3.498e-05         U        No
# ----------------------------------------------------------------------
# Guide freq.=42.07456895660128
# Fit Results
# ----------------------------------------------------------------------
# Parameter                  Value        ± Error      Unit     Fixed
# ----------------------------------------------------------------------
# Ar                     5.684e-04      2.089e-05         U        No
# Ai                    -4.698e-04      2.089e-05         U        No
# fo                       41.5395         0.0035       GHz        No
# df                        0.0915         0.0035       GHz        No
# re0                    2.467e-04      3.460e-05         U        No
# im0                   -2.750e-04      3.460e-05         U        No
# ----------------------------------------------------------------------
# Guide freq.=41.541107523404314
# Fit Results
# ----------------------------------------------------------------------
# Parameter                  Value        ± Error      Unit     Fixed
# ----------------------------------------------------------------------
# Ar                    -1.903e-05      2.119e-05         U        No
# Ai                    -7.445e-04      2.119e-05         U        No
# fo                       41.1337         0.0036       GHz        No
# df                        0.0923         0.0036       GHz        No
# re0                    3.534e-04      3.495e-05         U        No
# im0                    2.261e-05      3.495e-05         U        No
# ----------------------------------------------------------------------
# Guide freq.
-05         U        No
# ----------------------------------------------------------------------
# Guide freq.=23.917518572198585
# Fit Results
# ----------------------------------------------------------------------
# Parameter                  Value        ± Error      Unit     Fixed
# ----------------------------------------------------------------------
# Ar                    -3.851e-04      3.746e-05         U        No
# Ai                       -0.0013      3.746e-05         U        No
# fo                       24.5201         0.0035       GHz        No
# df                        0.0927         0.0035       GHz        No
# re0                    6.636e-04      6.165e-05         U        No
# im0                    1.891e-04      6.165e-05         U        No
# ----------------------------------------------------------------------
# Guide freq.=23.367015099974754
# Fit Results
# ----------------------------------------------------------------------
# Parameter                  Value        ± Error      Unit     Fixed
# ----------------------------------------------------------------------
# Ar                       -0.0014      3.828e-05         U        No
# Ai                    -1.733e-05      3.828e-05         U        No
# fo                       23.9616         0.0036       GHz        No
# df                        0.0940         0.0036       GHz        No
# re0                    1.874e-05      6.258e-05         U        No
# im0                    6.887e-04      6.258e-05         U        No
# ----------------------------------------------------------------------
# Guide freq.=22.78833412075988
# Fit Results
# ----------------------------------------------------------------------
# Parameter                  Value        ± Error      Unit     Fixed
# ----------------------------------------------------------------------
# Ar                    -3.268e-04      3.890e-05         U        No
# Ai                        0.0013      3.890e-05         U        No
# fo                       23.3672         0.0036       GHz        No
# df                        0.0936         0.0036       GHz        No
# re0                   -6.731e-04      6.367e-05         U        No
# im0                    1.716e-04      6.367e-05         U        No
# ----------------------------------------------------------------------
# Guide freq.=22.228148623349863
# Fit Results
# ----------------------------------------------------------------------
# Parameter                  Value        ± Error      Unit     Fixed
# ----------------------------------------------------------------------
# Ar                        0.0013      3.969e-05         U        No
# Ai                     6.084e-04      3.969e-05         U        No
# fo                       22.7758         0.0037       GHz        No
# df                        0.0940         0.0037       GHz        No
# re0                   -3.231e-04      6.488e-05         U        No
# im0                   -6.232e-04      6.488e-05         U        No
# ----------------------------------------------------------------------
# Guide freq.=21.68704605431964
# Fit Results
# ----------------------------------------------------------------------
# Parameter                  Value        ± Error      Unit     Fixed
# ----------------------------------------------------------------------
# Ar                     9.011e-04      4.086e-05         U        No
# Ai                       -0.0011      4.086e-05         U        No
# fo                       22.1895         0.0038       GHz        No
# df                        0.0956         0.0038       GHz        No
# re0                    5.199e-04      6.618e-05         U        No
# im0                   -4.564e-04      6.618e-05         U        No
# ----------------------------------------------------------------------
# Guide freq.=21.06986174015803
# Fit Results
# ----------------------------------------------------------------------
# Parameter                  Value        ± Error      Unit     Fixed
# ----------------------------------------------------------------------
# Ar                    -9.998e-04      4.218e-05         U        No
# Ai                       -0.0011      4.218e-05         U        No
# fo                       21.5579         0.0038       GHz        No
# df                        0.0959         0.0038       GHz        No
# re0                    5.360e-04      6.821e-05         U        No
# im0                    4.751e-04      6.821e-05         U        No
# ----------------------------------------------------------------------
# Guide freq.=20.51808234670253
# Fit Results
# ----------------------------------------------------------------------
# Parameter                  Value        ± Error      Unit     Fixed
# ----------------------------------------------------------------------
# Ar                       -0.0013      4.322e-05         U        No
# Ai                     8.080e-04      4.322e-05         U        No
# fo                       20.9524         0.0038       GHz        No
# df                        0.0959         0.0038       GHz        No
# re0                   -3.710e-04      6.990e-05         U        No
# im0                    6.201e-04      6.990e-05         U        No
# ----------------------------------------------------------------------
# Guide freq.=19.885947840545906
# Fit Results
# ----------------------------------------------------------------------
# Parameter                  Value        ± Error      Unit     Fixed
# ----------------------------------------------------------------------
# Ar                     6.991e-04      4.389e-05         U        No
# Ai                        0.0013      4.389e-05         U        No
# fo                       20.3040         0.0039       GHz        No
# df                        0.0969         0.0039       GHz        No
# re0                   -6.493e-04      7.061e-05         U        No
# im0                   -3.162e-04      7.061e-05         U        No
# ----------------------------------------------------------------------
# Guide freq.=19.292154980893667
# Fit Results
# ----------------------------------------------------------------------
# Parameter                  Value        ± Error      Unit     Fixed
# ----------------------------------------------------------------------
# Ar                        0.0014      4.458e-05         U        No
# Ai                    -5.749e-04      4.458e-05         U        No
# fo                       19.6528         0.0041       GHz        No
# df                        0.1000         0.0041       GHz        No
# re0                    2.417e-04      7.058e-05         U        No
# im0                   -6.549e-04      7.058e-05         U        No
# ----------------------------------------------------------------------
# Guide freq.=18.685439460680026
# Fit Results
# ----------------------------------------------------------------------
# Parameter                  Value        ± Error      Unit     Fixed
# ----------------------------------------------------------------------
# Ar                    -4.525e-04      4.547e-05         U        No
# Ai                       -0.0014      4.547e-05         U        No
# fo                       18.9934         0.0043       GHz        No
# df                        0.1020         0.0043       GHz        No
# re0                    6.592e-04      7.127e-05         U        No
# im0                    1.767e-04      7.127e-05         U        No
# ----------------------------------------------------------------------
# Guide freq.=18.035707439810214
# Fit Results
# ----------------------------------------------------------------------
# Parameter                  Value        ± Error      Unit     Fixed
# ----------------------------------------------------------------------
# Ar                       -0.0014      4.764e-05         U        No
# Ai                     5.256e-04      4.764e-05         U        No
# fo                       18.2828         0.0043       GHz        No
# df                        0.1027         0.0043       GHz        No
# re0                   -2.105e-04      7.435e-05         U        No
# im0                    6.629e-04      7.435e-05         U        No
# ----------------------------------------------------------------------
# Guide freq.=17.390358533599155
# Fit Results
# ----------------------------------------------------------------------
# Parameter                  Value        ± Error      Unit     Fixed
# ----------------------------------------------------------------------
# Ar                     5.306e-04      4.965e-05         U        No
# Ai                        0.0015      4.965e-05         U        No
# fo                       17.5974         0.0043       GHz        No
# df                        0.1023         0.0043       GHz        No
# re0                   -6.928e-04      7.769e-05         U        No
# im0                   -2.134e-04      7.769e-05         U        No
# ----------------------------------------------------------------------
# Guide freq.=16.71865062981335
# Fit Results
# ----------------------------------------------------------------------
# Parameter                  Value        ± Error      Unit     Fixed
# ----------------------------------------------------------------------
# Ar                        0.0015      5.146e-05         U        No
# Ai                    -6.602e-04      5.146e-05         U        No
# fo                       16.8798         0.0045       GHz        No
# df                        0.1045         0.0045       GHz        No
# re0                    2.718e-04      7.965e-05         U        No
# im0                   -6.816e-04      7.965e-05         U        No
# ----------------------------------------------------------------------
# Guide freq.=15.98466756856291
# Fit Results
# ----------------------------------------------------------------------
# Parameter                  Value        ± Error      Unit     Fixed
# ----------------------------------------------------------------------
# Ar                    -8.737e-04      5.308e-05         U        No
# Ai                       -0.0014      5.308e-05         U        No
# fo                       16.1265         0.0048       GHz        No
# df                        0.1088         0.0048       GHz        No
# re0                    6.269e-04      8.046e-05         U        No
# im0                    3.633e-04      8.046e-05         U        No
# ----------------------------------------------------------------------
# Guide freq.=15.240428524743988
# Fit Results
# ----------------------------------------------------------------------
# Parameter                  Value        ± Error      Unit     Fixed
# ----------------------------------------------------------------------
# Ar                       -0.0011      5.543e-05         U        No
# Ai                        0.0012      5.543e-05         U        No
# fo                       15.3333         0.0052       GHz        No
# df                        0.1125         0.0052       GHz        No
# re0                   -4.990e-04      8.254e-05         U        No
# im0                    5.168e-04      8.254e-05         U        No
# ----------------------------------------------------------------------
# Guide freq.=14.416049129685398
# Fit Results
# ----------------------------------------------------------------------
# Parameter                  Value        ± Error      Unit     Fixed
# ----------------------------------------------------------------------
# Ar                        0.0016      5.858e-05         U        No
# Ai                     6.960e-04      5.858e-05         U        No
# fo                       14.4894         0.0053       GHz        No
# df                        0.1139         0.0053       GHz        No
# re0                   -3.220e-04      8.662e-05         U        No
# im0                   -6.801e-04      8.662e-05         U        No
# ----------------------------------------------------------------------
# Guide freq.=13.569111835285645
# Fit Results
# ----------------------------------------------------------------------
# Parameter                  Value        ± Error      Unit     Fixed
# ----------------------------------------------------------------------
# Ar                     1.785e-04      6.211e-05         U        No
# Ai                       -0.0018      6.211e-05         U        No
# fo                       13.6622         0.0055       GHz        No
# df                        0.1165         0.0055       GHz        No
# re0                    7.808e-04      9.074e-05         U        No
# im0                   -1.031e-04      9.074e-05         U        No
# ----------------------------------------------------------------------
# Guide freq.=12.697650343257658
# Fit Results
# ----------------------------------------------------------------------
# Parameter                  Value        ± Error      Unit     Fixed
# ----------------------------------------------------------------------
# Ar                       -0.0017      6.513e-05         U        No
# Ai                     6.290e-04      6.513e-05         U        No
# fo                       12.7884         0.0059       GHz        No
# df                        0.1212         0.0059       GHz        No
# re0                   -2.573e-04      9.323e-05         U        No
# im0                    7.527e-04      9.323e-05         U        No
# ----------------------------------------------------------------------
# Guide freq.=11.672079714596745
# Fit Results
# ----------------------------------------------------------------------
# Parameter                  Value        ± Error      Unit     Fixed
# ----------------------------------------------------------------------
# Ar                        0.0016      6.759e-05         U        No
# Ai                     8.113e-04      6.759e-05         U        No
# fo                       11.7953         0.0065       GHz        No
# df                        0.1272         0.0065       GHz        No
# re0                   -3.552e-04      9.429e-05         U        No
# im0                   -7.017e-04      9.429e-05         U        No
# ----------------------------------------------------------------------
# Guide freq.=10.548015566462768
# Fit Results
# ----------------------------------------------------------------------
# Parameter                  Value        ± Error      Unit     Fixed
# ----------------------------------------------------------------------
# Ar                    -6.778e-04      6.921e-05         U        No
# Ai                       -0.0016      6.921e-05         U        No
# fo                       10.7424         0.0071       GHz        No
# df                        0.1318         0.0071       GHz        No
# re0                    6.857e-04      9.474e-05         U        No
# im0                    3.096e-04      9.474e-05         U        No
# ----------------------------------------------------------------------
# Guide freq.=9.35195394263961
# Fit Results
# ----------------------------------------------------------------------
# Parameter                  Value        ± Error      Unit     Fixed
# ----------------------------------------------------------------------
# Ar                    -4.005e-04      6.866e-05         U        No
# Ai                        0.0016      6.866e-05         U        No
# fo                        9.6531         0.0074       GHz        No
# df                        0.1346         0.0074       GHz        No
# re0                   -7.017e-04      9.294e-05         U        No
# im0                    1.613e-04      9.294e-05         U        No
# ----------------------------------------------------------------------

# %%
#Realoading parameters

# %%
data_L_fits = fits_storage.load_fit_results(newFile, group="Lorentzian fitting")

# %%
cut_data_L_fits = fits_storage.slice_dict(data_L_fits, 15, 72)

# %%
#Plotting of fitted parameters

# %%
fits_storage.plot_fit_parameters_subplots(
    data_L_fits,
    x_axis="field",
    params=["df", "fo"],
    x_label= "μ₀H (T)"
)
